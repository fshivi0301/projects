# %%
import numpy as np
X=np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
])
y=np.array([
    [0],
    [1],
    [1],
    [0]
]).ravel()

# %% [markdown]
# implementing using perceptron

# %%
from sklearn.neural_network import MLPRegressor
mlp_reg=MLPRegressor(max_iter=100000,solver="adam",random_state=42,early_stopping=False,tol=1e-12,activation="relu")
mlp_reg.fit(X,y)
mlp_reg.predict(X).round()
# Out:
# array([0., 1., 1., 0.])

# %%
def sigmoid(z):
    return 1/(1+np.exp(-z))
def der_sigmoid(a):
    return a*(1-a)
np.random.seed(42)
w1=np.random.randn(2,2)
w2=np.random.randn(2,1)
b1=np.random.randn(1,2)
b2=np.random.randn(1,1)
# now forward pass
z1=X @ w1+b1
a1=sigmoid(z1)
z2=a1 @ w2+b2
y_hat=sigmoid(z2)
# loss
loss=np.mean(y-y_hat)**2
#backward
dl_dyhat=2*(y_hat-y)/y.shape[0]
dyhat_da=der_sigmoid()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 19
#      17 #backward
#      18 dl_dyhat=2*(y_hat-y)/y.shape[0]
# ---> 19 dyhat_da=der_sigmoid()
#
# TypeError: der_sigmoid() missing 1 required positional argument: 'a'
